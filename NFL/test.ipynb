# %% [markdown]
# Using NFL Player Data from 1999 to predict player fantasy points

# %%
import nfl_data_py as nfl

# %%
nfl.import_weekly_rosters([2010])
# Out:
#        season team position depth_chart_position jersey_number status  \
# 0        2010  PIT        T                 None            71    ACT
# 1        2010  PIT        T                 None            71    ACT
# 2        2010  PIT        T                 None            71    ACT
# 3        2010  PIT        T                 None            71    ACT
# 4        2010  PIT        T                 None            71    ACT
# ...       ...  ...      ...                  ...           ...    ...
# 31921    2010  NYJ       DB                 None            29    CUT
# 31922    2010  NYJ       DB                 None            29    CUT
# 31923    2010  NYJ       DB                 None            29    CUT
# 31924    2010  CHI       LB                 None             0   None
# 31925    2010   NE       DB                 None             0   None
#
#           player_name first_name last_name birth_date  ...  \
# 0       Flozell Adams    Flozell     Adams 1975-05-18  ...
# ...
